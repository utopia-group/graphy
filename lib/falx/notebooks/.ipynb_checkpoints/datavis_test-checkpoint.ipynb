# %%
from vega import VegaLite
from ipywidgets import widgets
import os
os.chdir('/Users/lycoris/Google Drive/Code/datavis')
print(os.getcwd())
from lib.falx.visualization.chart import *
from lib.falx.utils.table_utils import load_and_clean_table
from lib.utils.csv_utils import *

dirname = 'eval'
# Out:
# /Users/lycoris/Google Drive/Code/datavis

# %%
data = load_and_clean_table(read_csv_to_dict('{}/data/simple.csv'.format(dirname)))
fname = 'gt/simple-test-3.vl.json'
with open(os.path.join(dirname, fname), "r") as f:
    vl_spec = json.load(f)
vis = VisDesign.load_from_vegalite(vl_spec, data)
print(vis.eval())
VegaLite(vis.to_vl_obj()).display()
# Out:
# [{'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, {'field': 'C', 'type': 'nominal'}, {'field': 'B', 'type': 'nominal'}]
# {'y': {'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, 'color': {'field': 'C', 'type': 'nominal'}, 'x': {'field': 'B', 'type': 'nominal'}, 'order': {'field': 'B', 'type': 'quantitative'}}
# {'y': {'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, 'color': {'field': 'C', 'type': 'nominal'}, 'x': {'field': 'B', 'type': 'nominal'}, 'order': {'field': 'B', 'type': 'quantitative'}}
# {'y': {'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, 'color': {'field': 'C', 'type': 'nominal'}, 'x': {'field': 'B', 'type': 'nominal'}, 'order': {'field': 'B', 'type': 'quantitative'}}
# {'y': {'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, 'color': {'field': 'C', 'type': 'nominal'}, 'x': {'field': 'B', 'type': 'nominal'}, 'order': {'field': 'B', 'type': 'quantitative'}}
# [Point(point_shape=None, shape=None, x='third', y=5.0, size=None, color='bing', column=None, presentation='line'), Point(point_shape=None, shape=None, x='fourth', y=6.0, size=None, color='bing', column=None, presentation='line'), Point(point_shape=None, shape=None, x='first', y=3.0, size=None, color='bing', column=None, presentation='line'), Point(point_shape=None, shape=None, x='second', y=4.0, size=None, color='bing', column=None, presentation='line'), Point(point_shape=None, shape=None, x='third', y=4.0, size=None, color='yi', column=None, presentation='line'), Point(point_shape=None, shape=None, x='fourth', y=5.0, size=None, color='yi', column=None, presentation='line'), Point(point_shape=None, shape=None, x='first', y=2.0, size=None, color='yi', column=None, presentation='line'), Point(point_shape=None, shape=None, x='second', y=3.0, size=None, color='yi', column=None, presentation='line'), Point(point_shape=None, shape=None, x='third', y=3.0, size=None, color='jia', column=None, presentation='line'), Point(point_shape=None, shape=None, x='fourth', y=4.0, size=None, color='jia', column=None, presentation='line'), Point(point_shape=None, shape=None, x='first', y=1.0, size=None, color='jia', column=None, presentation='line'), Point(point_shape=None, shape=None, x='second', y=2.0, size=None, color='jia', column=None, presentation='line'), Point(point_shape=None, shape=None, x='third', y=6.0, size=None, color='ding', column=None, presentation='line'), Point(point_shape=None, shape=None, x='fourth', y=7.0, size=None, color='ding', column=None, presentation='line'), Point(point_shape=None, shape=None, x='first', y=4.0, size=None, color='ding', column=None, presentation='line'), Point(point_shape=None, shape=None, x='second', y=5.0, size=None, color='ding', column=None, presentation='line')]

# %%
data = load_and_clean_table(read_csv_to_dict('{}/data/simple.csv'.format(dirname)))
fname = 'gt/simple-test-2.vl.json'
with open(os.path.join(dirname, fname), "r") as f:
    vl_spec = json.load(f)
vis = VisDesign.load_from_vegalite(vl_spec, data)
print(vis.eval())
VegaLite(vis.to_vl_obj()).display()
# Out:
# [{'field': 'A', 'type': 'quantitative', 'aggregate': 'mean'}, {'field': 'B', 'type': 'nominal'}]
# [BarV(x='first', y1=2.5, y2=None, color=None, column=None), BarV(x='second', y1=3.5, y2=None, color=None, column=None), BarV(x='fourth', y1=5.5, y2=None, color=None, column=None), BarV(x='third', y1=4.5, y2=None, color=None, column=None)]

# %%
data = load_and_clean_table(read_csv_to_dict('{}/data/movies.csv'.format(dirname)))
fname = 'gt/movies-test-2.vl.json'
with open(os.path.join(dirname, fname), "r") as f:
    vl_spec = json.load(f)
vis = VisDesign.load_from_vegalite(vl_spec, data)
print(vis.eval())
VegaLite(vis.to_vl_obj()).display()
# Out:
# [{'field': 'Worldwide Gross', 'type': 'quantitative', 'aggregate': 'mean'}, {'field': 'Genre', 'type': 'nominal'}, {'field': 'Release Year', 'type': 'temporal'}]
# [BarV(x=1996, y1=151947179.0, y2=None, color='Musical', column=None), BarV(x=1997, y1=139801410.0, y2=None, color='Musical', column=None), BarV(x=2002, y1=307687518.0, y2=None, color='Musical', column=None), BarV(x=2004, y1=158225796.0, y2=None, color='Musical', column=None), BarV(x=2006, y1=154965956.0, y2=None, color='Musical', column=None), BarV(x=2007, y1=202823091.0, y2=None, color='Musical', column=None), BarV(x=1998, y1=19080435.0, y2=None, color='Black Comedy', column=None), BarV(x=1999, y1=21322057.666666668, y2=None, color='Black Comedy', column=None), BarV(x=2000, y1=27732366.0, y2=None, color='Black Comedy', column=None), BarV(x=2001, y1=71430876.0, y2=None, color='Black Comedy', column=None), BarV(x=2007, y1=2426851.0, y2=None, color='Black Comedy', column=None), BarV(x=2009, y1=67348218.0, y2=None, color='Black Comedy', column=None), BarV(x=1996, y1=99387812.0, y2=None, color='Horror', column=None), BarV(x=1997, y1=53997717.0, y2=None, color='Horror', column=None), BarV(x=1998, y1=39727769.2, y2=None, color='Horror', column=None), BarV(x=1999, y1=129386264.75, y2=None, color='Horror', column=None), BarV(x=2000, y1=129755619.5, y2=None, color='Horror', column=None), BarV(x=2001, y1=350100280.0, y2=None, color='Horror', column=None), BarV(x=2002, y1=176440712.5, y2=None, color='Horror', column=None), BarV(x=2003, y1=85776793.75, y2=None, color='Horror', column=None), BarV(x=2004, y1=102290765.0, y2=None, color='Horror', column=None), BarV(x=2005, y1=66050729.333333336, y2=None, color='Horror', column=None), BarV(x=2006, y1=163876815.0, y2=None, color='Horror', column=None), BarV(x=2007, y1=234019801.66666666, y2=None, color='Horror', column=None), BarV(x=2009, y1=113584959.33333333, y2=None, color='Horror', column=None), BarV(x=2000, y1=71189835.0, y2=None, color='Western', column=None), BarV(x=2003, y1=53273576.0, y2=None, color='Western', column=None), BarV(x=2004, y1=107336658.0, y2=None, color='Western', column=None), BarV(x=2007, y1=69791889.0, y2=None, color='Western', column=None), BarV(x=1996, y1=104061323.08333333, y2=None, color='Comedy', column=None), BarV(x=1997, y1=189437449.16666666, y2=None, color='Comedy', column=None), BarV(x=1998, y1=92411914.42857143, y2=None, color='Comedy', column=None), BarV(x=1999, y1=108259610.08333333, y2=None, color='Comedy', column=None), BarV(x=2000, y1=118526917.78947368, y2=None, color='Comedy', column=None), BarV(x=2001, y1=105267850.5, y2=None, color='Comedy', column=None), BarV(x=2002, y1=116946604.5, y2=None, color='Comedy', column=None), BarV(x=2003, y1=155385203.0, y2=None, color='Comedy', column=None), BarV(x=2004, y1=111834900.73333333, y2=None, color='Comedy', column=None), BarV(x=2005, y1=186320742.75, y2=None, color='Comedy', column=None), BarV(x=2006, y1=164147839.0, y2=None, color='Comedy', column=None), BarV(x=2007, y1=211982490.0, y2=None, color='Comedy', column=None), BarV(x=2008, y1=118285221.6, y2=None, color='Comedy', column=None), BarV(x=2009, y1=124172582.4, y2=None, color='Comedy', column=None), BarV(x=2010, y1=43149143.0, y2=None, color='Comedy', column=None), BarV(x=1996, y1=84761363.25, y2=None, color='Drama', column=None), BarV(x=1997, y1=74084207.71428572, y2=None, color='Drama', column=None), BarV(x=1998, y1=102350126.72222222, y2=None, color='Drama', column=None), BarV(x=1999, y1=89459315.45454545, y2=None, color='Drama', column=None), BarV(x=2000, y1=140591280.3125, y2=None, color='Drama', column=None), BarV(x=2001, y1=78961061.6923077, y2=None, color='Drama', column=None), BarV(x=2002, y1=135072430.4, y2=None, color='Drama', column=None), BarV(x=2003, y1=114283427.77777778, y2=None, color='Drama', column=None), BarV(x=2004, y1=180292456.4, y2=None, color='Drama', column=None), BarV(x=2005, y1=108452988.44444445, y2=None, color='Drama', column=None), BarV(x=2006, y1=78049866.78947368, y2=None, color='Drama', column=None), BarV(x=2007, y1=55691693.4, y2=None, color='Drama', column=None), BarV(x=2008, y1=149695594.0, y2=None, color='Drama',  ...

# %%
data = load_and_clean_table(read_csv_to_dict('{}/data/cars.csv'.format(dirname)))
fname = 'gt/cars-test-2.vl.json'
with open(os.path.join(dirname, fname), "r") as f:
    vl_spec = json.load(f)
vis = VisDesign.load_from_vegalite(vl_spec, data)
print(vis.eval())
VegaLite(vis.to_vl_obj()).display()
# Out:
# [{'field': 'MPG', 'type': 'quantitative', 'bin': True}, {'field': 'MPG', 'type': 'quantitative', 'aggregate': 'count'}]
# [BarV(x=26.0, y1=26.0, y2=None, color=None, column=None), BarV(x=26.0, y1=26.0, y2=None, color=None, column=None), BarV(x=43.1, y1=43.1, y2=None, color=None, column=None), BarV(x=44.3, y1=44.3, y2=None, color=None, column=None), BarV(x=43.4, y1=43.4, y2=None, color=None, column=None), BarV(x=29.0, y1=29.0, y2=None, color=None, column=None), BarV(x=31.0, y1=31.0, y2=None, color=None, column=None), BarV(x=29.0, y1=29.0, y2=None, color=None, column=None), BarV(x=32.8, y1=32.8, y2=None, color=None, column=None), BarV(x=44.0, y1=44.0, y2=None, color=None, column=None), BarV(x=33.0, y1=33.0, y2=None, color=None, column=None), BarV(x=33.0, y1=33.0, y2=None, color=None, column=None), BarV(x=23.0, y1=23.0, y2=None, color=None, column=None), BarV(x=36.0, y1=36.0, y2=None, color=None, column=None), BarV(x=39.1, y1=39.1, y2=None, color=None, column=None), BarV(x=27.0, y1=27.0, y2=None, color=None, column=None), BarV(x=24.5, y1=24.5, y2=None, color=None, column=None), BarV(x=38.1, y1=38.1, y2=None, color=None, column=None), BarV(x=35.1, y1=35.1, y2=None, color=None, column=None), BarV(x=32.0, y1=32.0, y2=None, color=None, column=None), BarV(x=29.8, y1=29.8, y2=None, color=None, column=None), BarV(x=37.7, y1=37.7, y2=None, color=None, column=None), BarV(x=34.7, y1=34.7, y2=None, color=None, column=None), BarV(x=38.0, y1=38.0, y2=None, color=None, column=None), BarV(x=39.0, y1=39.0, y2=None, color=None, column=None), BarV(x=31.0, y1=31.0, y2=None, color=None, column=None), BarV(x=34.1, y1=34.1, y2=None, color=None, column=None), BarV(x=31.8, y1=31.8, y2=None, color=None, column=None), BarV(x=37.2, y1=37.2, y2=None, color=None, column=None), BarV(x=46.6, y1=46.6, y2=None, color=None, column=None), BarV(x=37.0, y1=37.0, y2=None, color=None, column=None), BarV(x=34.4, y1=34.4, y2=None, color=None, column=None), BarV(x=29.9, y1=29.9, y2=None, color=None, column=None), BarV(x=36.1, y1=36.1, y2=None, color=None, column=None), BarV(x=31.0, y1=31.0, y2=None, color=None, column=None), BarV(x=26.0, y1=26.0, y2=None, color=None, column=None), BarV(x=31.0, y1=31.0, y2=None, color=None, column=None), BarV(x=30.0, y1=30.0, y2=None, color=None, column=None), BarV(x=36.4, y1=36.4, y2=None, color=None, column=None), BarV(x=30.0, y1=30.0, y2=None, color=None, column=None), BarV(x=44.6, y1=44.6, y2=None, color=None, column=None), BarV(x=32.3, y1=32.3, y2=None, color=None, column=None), BarV(x=32.0, y1=32.0, y2=None, color=None, column=None), BarV(x=38.0, y1=38.0, y2=None, color=None, column=None), BarV(x=31.5, y1=31.5, y2=None, color=None, column=None), BarV(x=29.5, y1=29.5, y2=None, color=None, column=None), BarV(x=34.1, y1=34.1, y2=None, color=None, column=None), BarV(x=37.0, y1=37.0, y2=None, color=None, column=None), BarV(x=31.0, y1=31.0, y2=None, color=None, column=None), BarV(x=35.0, y1=35.0, y2=None, color=None, column=None), BarV(x=26.0, y1=26.0, y2=None, color=None, column=None), BarV(x=37.3, y1=37.3, y2=None, color=None, column=None), BarV(x=30.0, y1=30.0, y2=None, color=None, column=None), BarV(x=26.0, y1=26.0, y2=None, color=None, column=None), BarV(x=29.0, y1=29.0, y2=None, color=None, column=None), BarV(x=29.0, y1=29.0, y2=None, color=None, column=None), BarV(x=32.0, y1=32.0, y2=None, color=None, column=None), BarV(x=33.5, y1=33.5, y2=None, color=None, column=None), BarV(x=39.4, y1=39.4, y2=None, color=None, column=None), BarV(x=34.2, y1=34.2, y2=None, color=None, column=None), BarV(x=34.5, y1=34.5, y2=None, color=None, column=None), BarV(x=36.0, y1=36.0, y2=None, color=None, column=None), BarV(x=34.0, y1=34.0, y2=None, color=None, column=None), BarV(x=31.5, y1=31.5, y2=None, color=None, column=None), BarV(x=31.9, y1=31.9, y2=None, color=None, column=None), BarV(x=27.2, y1=27.2, y2=None, color=None, column=None), BarV(x=22.0, y1=22.0, y2=None, color=None, column=None), BarV(x=21.0, y1=21.0, y2=None, color=None, column=None), BarV(x=15.0, y1=15.0, y2=None, color=None, column=None), BarV(x=15.0, y1=15.0, y2=None, color=None, column=None), BarV(x=26 ...

# %%
data = load_and_clean_table(read_csv_to_dict('{}/data/movies.csv'.format(dirname)))
fname = 'gt/movies-test.vl.json'
with open(os.path.join(dirname, fname), "r") as f:
    vl_spec = json.load(f)
vis = VisDesign.load_from_vegalite(vl_spec, data)
print(vis.eval())
VegaLite(vis.to_vl_obj()).display()
# Out:
# [{'field': 'Production Budget', 'type': 'quantitative', 'aggregate': 'mean'}, {'field': 'Release Year', 'type': 'temporal'}]
# group data: {(None, None, None): [{'Title': 'From Dusk Till Dawn', 'Worldwide Gross': 25728961, 'Production Budget': 20000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 107, 'Genre': 'Horror', 'Creative Type': 'Fantasy', 'Rotten Tomatoes Rating': 63, 'IMDB Rating': 7.1}, {'Title': 'Broken Arrow', 'Worldwide Gross': 148345997, 'Production Budget': 65000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 108, 'Genre': 'Action', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 55, 'IMDB Rating': 5.8}, {'Title': 'City Hall', 'Worldwide Gross': 20278055, 'Production Budget': 40000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 111, 'Genre': 'Drama', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 55, 'IMDB Rating': 6.1}, {'Title': 'Happy Gilmore', 'Worldwide Gross': 38623460, 'Production Budget': 10000000, 'Release Year': 1996, 'Content Rating': 'PG-13', 'Running Time': 92, 'Genre': 'Comedy', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 58, 'IMDB Rating': 6.9}, {'Title': 'Fargo', 'Worldwide Gross': 51204567, 'Production Budget': 7000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 87, 'Genre': 'Thriller', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 94, 'IMDB Rating': 8.3}, {'Title': 'The Craft', 'Worldwide Gross': 55669466, 'Production Budget': 15000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 100, 'Genre': 'Thriller', 'Creative Type': 'Fantasy', 'Rotten Tomatoes Rating': 45, 'IMDB Rating': 5.9}, {'Title': 'Twister', 'Worldwide Gross': 495900000, 'Production Budget': 88000000, 'Release Year': 1996, 'Content Rating': 'PG-13', 'Running Time': 117, 'Genre': 'Action', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 57, 'IMDB Rating': 6.0}, {'Title': 'Dragonheart', 'Worldwide Gross': 104364680, 'Production Budget': 57000000, 'Release Year': 1996, 'Content Rating': 'PG-13', 'Running Time': 108, 'Genre': 'Adventure', 'Creative Type': 'Fantasy', 'Rotten Tomatoes Rating': 50, 'IMDB Rating': 6.2}, {'Title': 'The Phantom', 'Worldwide Gross': 17220599, 'Production Budget': 45000000, 'Release Year': 1996, 'Content Rating': 'PG', 'Running Time': 100, 'Genre': 'Action', 'Creative Type': 'Super Hero', 'Rotten Tomatoes Rating': 43, 'IMDB Rating': 4.8}, {'Title': 'The Rock', 'Worldwide Gross': 336069511, 'Production Budget': 75000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 136, 'Genre': 'Action', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 66, 'IMDB Rating': 7.2}, {'Title': 'The Cable Guy', 'Worldwide Gross': 102825796, 'Production Budget': 47000000, 'Release Year': 1996, 'Content Rating': 'PG-13', 'Running Time': 95, 'Genre': 'Comedy', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 52, 'IMDB Rating': 5.8}, {'Title': 'Eraser', 'Worldwide Gross': 234400000, 'Production Budget': 100000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 115, 'Genre': 'Action', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 34, 'IMDB Rating': 5.9}, {'Title': 'The Hunchback of Notre Dame', 'Worldwide Gross': 325500000, 'Production Budget': 100000000, 'Release Year': 1996, 'Content Rating': 'G', 'Running Time': 86, 'Genre': 'Adventure', 'Creative Type': 'Historical Fiction', 'Rotten Tomatoes Rating': 73, 'IMDB Rating': 6.5}, {'Title': 'The Nutty Professor', 'Worldwide Gross': 273814019, 'Production Budget': 55000000, 'Release Year': 1996, 'Content Rating': 'PG-13', 'Running Time': 95, 'Genre': 'Comedy', 'Creative Type': 'Kids Fiction', 'Rotten Tomatoes Rating': 67, 'IMDB Rating': 5.6}, {'Title': 'Striptease', 'Worldwide Gross': 32773011, 'Production Budget': 50000000, 'Release Year': 1996, 'Content Rating': 'R', 'Running Time': 115, 'Genre': 'Comedy', 'Creative Type': 'Contemporary Fiction', 'Rotten Tomatoes Rating': 12, 'IMDB Rating': 3.9}, {'Title': 'Independence Day', 'Worldwide Gross' ...
# [Line(x1=1996, y1=20000000, x2=1996, y2=65000000, size=None, color=None, column=None), Line(x1=1996, y1=65000000, x2=1996, y2=40000000, size=None, color=None, column=None), Line(x1=1996, y1=40000000, x2=1996, y2=10000000, size=None, color=None, column=None), Line(x1=1996, y1=10000000, x2=1996, y2=7000000, size=None, color=None, column=None), Line(x1=1996, y1=7000000, x2=1996, y2=15000000, size=None, color=None, column=None), Line(x1=1996, y1=15000000, x2=1996, y2=88000000, size=None, color=None, column=None), Line(x1=1996, y1=88000000, x2=1996, y2=57000000, size=None, color=None, column=None), Line(x1=1996, y1=57000000, x2=1996, y2=45000000, size=None, color=None, column=None), Line(x1=1996, y1=45000000, x2=1996, y2=75000000, size=None, color=None, column=None), Line(x1=1996, y1=75000000, x2=1996, y2=47000000, size=None, color=None, column=None), Line(x1=1996, y1=47000000, x2=1996, y2=100000000, size=None, color=None, column=None), Line(x1=1996, y1=100000000, x2=1996, y2=100000000, size=None, color=None, column=None), Line(x1=1996, y1=100000000, x2=1996, y2=55000000, size=None, color=None, column=None), Line(x1=1996, y1=55000000, x2=1996, y2=50000000, size=None, color=None, column=None), Line(x1=1996, y1=50000000, x2=1996, y2=75000000, size=None, color=None, column=None), Line(x1=1996, y1=75000000, x2=1996, y2=32000000, size=None, color=None, column=None), Line(x1=1996, y1=32000000, x2=1996, y2=46000000, size=None, color=None, column=None), Line(x1=1996, y1=46000000, x2=1996, y2=45000000, size=None, color=None, column=None), Line(x1=1996, y1=45000000, x2=1996, y2=3100000, size=None, color=None, column=None), Line(x1=1996, y1=3100000, x2=1996, y2=40000000, size=None, color=None, column=None), Line(x1=1996, y1=40000000, x2=1996, y2=25000000, size=None, color=None, column=None), Line(x1=1996, y1=25000000, x2=1996, y2=25000000, size=None, color=None, column=None), Line(x1=1996, y1=25000000, x2=1996, y2=55000000, size=None, color=None, column=None), Line(x1=1996, y1=55000000, x2=1996, y2=50000000, size=None, color=None, column=None), Line(x1=1996, y1=50000000, x2=1996, y2=45000000, size=None, color=None, column=None), Line(x1=1996, y1=45000000, x2=1996, y2=45000000, size=None, color=None, column=None), Line(x1=1996, y1=45000000, x2=1996, y2=55000000, size=None, color=None, column=None), Line(x1=1996, y1=55000000, x2=1996, y2=40000000, size=None, color=None, column=None), Line(x1=1996, y1=40000000, x2=1996, y2=30000000, size=None, color=None, column=None), Line(x1=1996, y1=30000000, x2=1996, y2=38000000, size=None, color=None, column=None), Line(x1=1996, y1=38000000, x2=1996, y2=2500000, size=None, color=None, column=None), Line(x1=1996, y1=2500000, x2=1996, y2=55000000, size=None, color=None, column=None), Line(x1=1996, y1=55000000, x2=1996, y2=65000000, size=None, color=None, column=None), Line(x1=1996, y1=65000000, x2=1996, y2=44000000, size=None, color=None, column=None), Line(x1=1996, y1=44000000, x2=1996, y2=9000000, size=None, color=None, column=None), Line(x1=1996, y1=9000000, x2=1996, y2=70000000, size=None, color=None, column=None), Line(x1=1996, y1=70000000, x2=1996, y2=42000000, size=None, color=None, column=None), Line(x1=1996, y1=42000000, x2=1996, y2=35000000, size=None, color=None, column=None), Line(x1=1996, y1=35000000, x2=1996, y2=80000000, size=None, color=None, column=None), Line(x1=1996, y1=80000000, x2=1996, y2=60000000, size=None, color=None, column=None), Line(x1=1996, y1=60000000, x2=1996, y2=5500000, size=None, color=None, column=None), Line(x1=1996, y1=5500000, x2=1996, y2=80000000, size=None, color=None, column=None), Line(x1=1996, y1=80000000, x2=1996, y2=80000000, size=None, color=None, column=None), Line(x1=1996, y1=80000000, x2=1996, y2=50000000, size=None, color=None, column=None), Line(x1=1996, y1=50000000, x2=1996, y2=12000000, size=None, color=None, column=None), Line(x1=1996, y1=12000000, x2=1996, y2=21500000, size=None, color=None, column=None), Line(x1=1996, y1=21500000, x2=1996, y2=15000000,  ...
